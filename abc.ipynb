# %%
import cv2

# Load classifiers outside the loop for efficiency
face_cascade = cv2.CascadeClassifier("Haarcascade_frontalface_default.xml")
eye_cascade = cv2.CascadeClassifier("haarcascade_eye.xml")

# Use grayscale frames for detection (often faster)
def process_frame(frame):
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces and eyes in one pass
    faces = face_cascade.detectMultiScale(gray, 1.1, 9)
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
        roi_gray = gray[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray, 1.1, 9)
        for (ex, ey, ew, eh) in eyes:
            cv2.rectangle(frame, (x+ex, y+ey), (x+ex+ew, y+ey+eh), (0, 255, 0), 2)

    # Flip the frame
    gray_flip = cv2.flip(frame, 1)
    return gray_flip

video = cv2.VideoCapture(0)

while True:
    check, frame = video.read()
    if not check:
        break  # Handle potential errors during video capture

    flipped_frame = process_frame(frame)

    cv2.imshow("Flipped Video", flipped_frame)  # Updated window title
    key = cv2.waitKey(1)
    if key == ord('q'):
        break

video.release()
cv2.destroyAllWindows()
# Out:
# [ERROR:0@0.015] global persistence.cpp:519 open Can't open file: 'Haarcascade_frontalface_default.xml' in read mode
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 31
#      28 if not check:
#      29     break  # Handle potential errors during video capture
# ---> 31 flipped_frame = process_frame(frame)
#      33 cv2.imshow("Flipped Video", flipped_frame)  # Updated window title
#      34 key = cv2.waitKey(1)
#
# Cell In[1], line 12, in process_frame(frame)
#       9 gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#      11 # Detect faces and eyes in one pass
# ---> 12 faces = face_cascade.detectMultiScale(gray, 1.1, 9)
#      13 for (x, y, w, h) in faces:
#      14     cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
#
# ...

# %%
import cv2
face_cascade = cv2.CascadeClassifier("haarcascade_eye.xml")

# %%
pip install opencv-python
# Out:
# ...
#   Obtaining dependency information for opencv-python from https://files.pythonhosted.org/packages/c7/ec/9dabb6a9abfdebb3c45b0cc52dec901caafef2b2c7e7d6a839ed86d81e91/opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata
#   Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
# Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl (38.6 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
import numpy as np     # Numpy module will be used for horizontal stacking of two frames

video=cv2.VideoCapture(0)
a=0
while True:
    a=a+1
    check, frame= video.read()
    
     # Loading the required haar-cascade xml classifier file 
    face_detector = cv2.CascadeClassifier('Haarcascade_frontalface_default.xml') 
    eye_detector = cv2.CascadeClassifier('haarcascade_eye.xml')
    
    # Applying the face detection method on the grayscale image 
    faces_rect = face_detector.detectMultiScale(frame, 1.1, 9) 
    faces_rect_1 = eye_detector.detectMultiScale(frame, 1.1, 9)
    
    # Iterating through rectangles of detected faces 
    for (x, y, w, h) in faces_rect: 
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2) 
    for (x, y, w, h) in faces_rect_1: 
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
        
    # Fliping the image as said in question
    gray_flip = cv2.flip(frame,1)

    # Combining the two different image frames in one window
     
    cv2.imshow('frame', gray_flip )
    
    
    # Displaying the single window
    
    key=cv2.waitKey(1)
    
    cv2.imshow('frame', gray_flip )

    if key==ord('q'):
        break
print(a)

video.release()
cv2.destroyAllWindows
# Out:
# 63
# <function destroyAllWindows>

# %%
import numpy as np
import cv2 as cv
cap = cv.VideoCapture(0)
# Define the codec and create VideoWriter object
fourcc = cv.VideoWriter_fourcc(*'XVID')
out = cv.VideoWriter('output.avi', fourcc, 20.0, (640, 480))
while cap.isOpened():
 ret, frame = cap.read()
 if not ret:
  print("Can't receive frame (stream end?). Exiting ...")
  break
 frame = cv.flip(frame, 1)
 # write the flipped frame
 out.write(frame)
 cv.imshow('frame', frame)
 if cv.waitKey(1) == ord('q'):
  break
# Release everything if job is finished
cap.release()
out.release()
cv.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x2fc4e40) is not the object's thread (0x2be9110).
# Cannot move to target thread (0x2fc4e40)
#
# QObject::moveToThread: Current thread (0x2fc4e40) is not the object's thread (0x2be9110).
# Cannot move to target thread (0x2fc4e40)
#
# QObject::moveToThread: Current thread (0x2fc4e40) is not the object's thread (0x2be9110).
# Cannot move to target thread (0x2fc4e40)
#
# QObject::moveToThread: Current thread (0x2fc4e40) is not the object's thread (0x2be9110).
# Cannot move to target thread (0x2fc4e40)
#
# QObject::moveToThread: Current thread (0x2fc4e40) is not the object's thread (0x2be9110).
# Cannot move to target thread (0x2fc4e40)
#
# QObject::moveToThread: Current thread (0x2fc4e40) is not the object's thread (0x2be9110).
# Cannot move to target thread (0x2fc4e40)
#
# QObject::moveToThread: Current thread (0x2fc4e40) is not the object's thread (0x2be9110).
# Cannot move to target thread (0x2fc4e40)
#
# ...

# %%
import cv2

# Load classifiers with error handling
try:
    face_cascade = cv2.CascadeClassifier("face.xml")
    eye_cascade = cv2.CascadeClassifier("haarcascade_eye.xml")
    smile_cascade = cv2.CascadeClassifier("haarcascade_smile.xml")
    wallclock_cascade = cv2.CascadeClassifier("haarcascade_wallclock.xml")
except cv2.error as e:
    print("Error loading classifiers:", e)
    exit()

# Customize font (optional)
font = cv2.FONT_HERSHEY_SIMPLEX
font_scale = 0.7
font_color = (0, 255, 0)  # Green text

def process_frame(frame):
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces, eyes, smiles, and wall clocks
    faces = face_cascade.detectMultiScale(gray, 1.1, 9)
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
        cv2.putText(frame, "Face", (x, y-5), font, font_scale, font_color, 2)

        roi_gray = gray[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray, 1.1, 9)
        for (ex, ey, ew, eh) in eyes:
            cv2.rectangle(frame, (x+ex, y+ey), (x+ex+ew, y+ey+eh), (0, 255, 0), 2)
            cv2.putText(frame, "Eye", (x+ex, y+ey-5), font, font_scale, font_color, 2)
        smiles = smile_cascade.detectMultiScale(roi_gray, 1.1, 9)
        for (sx, sy, sw, sh) in smiles:
            cv2.rectangle(frame, (x+sx, y+sy), (x+sx+sw, y+sy+sh), (0, 0, 255), 2)
            cv2.putText(frame, "Smile", (x+sx, y+sy-5), font, font_scale, (0, 0, 255), 2)

    wallclock = wallclock_cascade.detectMultiScale(gray, 1.7, 22)
    for (x, y, w, h) in wallclock:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
        cv2.putText(frame, "wallclock", (x, y-5), font, font_scale, font_color, 2)

    return frame

# Open video capture with error handling
try:
    video = cv2.VideoCapture(0)
except cv2.error as e:
    print("Error opening video capture:", e)
    exit()

while True:
    check, frame = video.read()
    if not check:
        print("Error reading frame from video capture")
        break  # Exit loop on capture error

    try:
        processed_frame = process_frame(frame)
        cv2.imshow("Flipped Video", processed_frame)
    except Exception as e:
        print("Error processing frame:", e)

    key = cv2.waitKey(1)
    if key == ord('q'):
        break

# Ensure proper resource cleanup
try:
    video.release()
    cv2.destroyAllWindows()
except cv2.error as e:
    print("Error releasing resources:", e)
# Out:
# QObject::moveToThread: Current thread (0x4b5e010) is not the object's thread (0x4c87d20).
# Cannot move to target thread (0x4b5e010)
#
# QObject::moveToThread: Current thread (0x4b5e010) is not the object's thread (0x4c87d20).
# Cannot move to target thread (0x4b5e010)
#
# QObject::moveToThread: Current thread (0x4b5e010) is not the object's thread (0x4c87d20).
# Cannot move to target thread (0x4b5e010)
#
# QObject::moveToThread: Current thread (0x4b5e010) is not the object's thread (0x4c87d20).
# Cannot move to target thread (0x4b5e010)
#
# QObject::moveToThread: Current thread (0x4b5e010) is not the object's thread (0x4c87d20).
# Cannot move to target thread (0x4b5e010)
#
# QObject::moveToThread: Current thread (0x4b5e010) is not the object's thread (0x4c87d20).
# Cannot move to target thread (0x4b5e010)
#
# QObject::moveToThread: Current thread (0x4b5e010) is not the object's thread (0x4c87d20).
# Cannot move to target thread (0x4b5e010)
#
# ...

# %%
import cv2

# Load classifiers outside the loop for efficiency
face_cascade = cv2.CascadeClassifier("face.xml")
eye_cascade = cv2.CascadeClassifier("haarcascade_eye.xml")
smile_cascade = cv2.CascadeClassifier("haarcascade_smile.xml")
wallclock_cascade = cv2.CascadeClassifier("haarcascade_wallclock.xml")

# Customize font for titles (optional)
font = cv2.FONT_HERSHEY_SIMPLEX
font_scale = 0.7
font_color = (0, 255, 0) # Green text

def process_frame(frame):
   
  gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
  # Detect faces and eyes in one pass
  faces = face_cascade.detectMultiScale(gray, 1.1, 9)
  for (x, y, w, h) in faces:
    cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
    cv2.putText(frame, "Face", (x, y-5), font, font_scale, font_color, 2)


    roi_gray = gray[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray, 1.1, 9)
    for (ex, ey, ew, eh) in eyes:
      cv2.rectangle(frame, (x+ex, y+ey), (x+ex+ew, y+ey+eh), (0, 255, 0), 2)
      cv2.putText(frame, "Eye", (x+ex, y+ey-5), font, font_scale, font_color, 2)
    smiles = smile_cascade.detectMultiScale(roi_gray, 1.1, 9)
    for (sx, sy, sw, sh) in smiles:
      cv2.rectangle(frame, (x+sx, y+sy), (x+sx+sw, y+sy+sh), (0, 0, 255), 2)
      cv2.putText(frame, "Smile", (x+sx, y+sy-5), font, font_scale, (0, 0, 255), 2)

  wallclock = wallclock_cascade.detectMultiScale(gray, 1.7, 22)
  for (x, y, w, h) in wallclock:
    cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
    cv2.putText(frame, "wallclock", (x, y-5), font, font_scale, font_color, 2)
    
   
  return frame
 
video = cv2.VideoCapture(0)

while True:
  check, frame = video.read()
  if not check:
    break # Handle potential errors during video capture

  flipped_frame = process_frame(frame)

  cv2.imshow("Flipped Video", flipped_frame) # Updated window title
  key = cv2.waitKey(1)
  if key == ord('q'):
    break

video.release()
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x3b2c7e0) is not the object's thread (0x3b7bd30).
# Cannot move to target thread (0x3b2c7e0)
#
# QObject::moveToThread: Current thread (0x3b2c7e0) is not the object's thread (0x3b7bd30).
# Cannot move to target thread (0x3b2c7e0)
#
# QObject::moveToThread: Current thread (0x3b2c7e0) is not the object's thread (0x3b7bd30).
# Cannot move to target thread (0x3b2c7e0)
#
# QObject::moveToThread: Current thread (0x3b2c7e0) is not the object's thread (0x3b7bd30).
# Cannot move to target thread (0x3b2c7e0)
#
# QObject::moveToThread: Current thread (0x3b2c7e0) is not the object's thread (0x3b7bd30).
# Cannot move to target thread (0x3b2c7e0)
#
# QObject::moveToThread: Current thread (0x3b2c7e0) is not the object's thread (0x3b7bd30).
# Cannot move to target thread (0x3b2c7e0)
#
# QObject::moveToThread: Current thread (0x3b2c7e0) is not the object's thread (0x3b7bd30).
# Cannot move to target thread (0x3b2c7e0)
#
# ...
